# %% [markdown]
# # RF: NFL-Way Text Cleaning
#
# Standard NLP pipelines throw away signal that matters in scouting:
#
# | Problem | Example | Fix |
# |---------|---------|-----|
# | NLTK drops directional adjectives | "low" in "low pad level" → gone | **Un-stop** high-value directional words |
# | Generic filler clogs the vocabulary | "prospect", "player", "shows" in every report | **Custom stop words** for scouting domain |
# | Compound phrases split into noise | "change of direction" → 3 useless unigrams | **Phrase stitching**: `change_of_direction` |
#
# This notebook applies all three fixes and inspects the resulting vocabulary before any modeling.

# %% [markdown]
# ## 1. Imports & Controls

# %%
import re
import warnings
import numpy as np
import pandas as pd
from collections import Counter

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

nltk.download('stopwords', quiet=True)
nltk.download('wordnet',   quiet=True)
nltk.download('omw-1.4',  quiet=True)
nltk.download('punkt',    quiet=True)
warnings.filterwarnings('ignore')

# ── Controls ──────────────────────────────────────────────────────────────────
YEAR_MIN   = 2014
YEAR_MAX   = 2021
GRADE_MAX  = 6.4
TARGET     = 'made_it_contract'
RANDOM_STATE = 42

# Outcome-leaking phrases removed before any processing
PHRASE_BLOCKLIST = [
    'undrafted free agent', 'practice squad', 'free agent', 'early starter',
    'pro bowl', 'late round', 'undrafted free', 'make roster', 'rostered',
]

# Bigram discovery: minimum corpus frequency to consider a phrase
AUTO_PHRASE_MIN_FREQ = 15
AUTO_PHRASE_TOP_N    = 60

# %% [markdown]
# ## 2. Load & Combine Text

# %%
df = pd.read_csv('../data/processed/draft_enriched_with_contracts.csv')
df = df[(df['year'] >= YEAR_MIN) & (df['year'] <= YEAR_MAX)].copy()
df = df[df['grade'] <= GRADE_MAX].copy()
df = df.dropna(subset=[TARGET, 'grade', 'Pos_Group']).copy()
df[TARGET] = df[TARGET].astype(int)

# Combine all three text fields (same convention as other RF notebooks)
def combine_text(row):
    parts = [str(row.get(c, '') or '') for c in ['overview', 'strengths', 'weaknesses']]
    return ' '.join(p for p in parts if p.strip())

df['combined_text'] = df.apply(combine_text, axis=1)
df = df[df['combined_text'].str.strip() != ''].reset_index(drop=True)

print(f'Players: {len(df)}')
print(f'Positive rate ({TARGET}): {df[TARGET].mean():.1%}')
print(f'\nPer Pos_Group:')
print(df['Pos_Group'].value_counts().to_string())
# Out:
# Players: 3139
# Positive rate (made_it_contract): 27.7%
#
# Per Pos_Group:
# Pos_Group
# DB         601
# OL         527
# WR         456
# EDGE       385
# RB         299
# DT         246
# LB         233
# TE         183
# QB         126
# SPECIAL     83

# %% [markdown]
# ## 3. NFL-Way Cleaning
#
# Three steps applied in order:
# 1. **Custom stop words** — un-stop directional adjectives, add domain-filler stops
# 2. **Phrase stitching** — Pass A (curated NFL terms) + Pass B (data-driven discovery)
# 3. **Preprocessing function** — regex → tokenize → filter → lemmatize

# %% [markdown]
# ### 3a. Custom Stop Words

# %%
# Words NLTK stops that we WANT to keep — directional / physical descriptors
KEEP_WORDS = {
    'high', 'low', 'heavy', 'light', 'deep', 'short', 'long', 'wide',
    'hard', 'soft', 'strong', 'quick', 'good', 'great', 'up', 'down',
    'off', 'out', 'over', 'through', 'above', 'below',
}

# Words to ADD to stop list — appear in nearly every scouting report, carry no discriminative signal
CUSTOM_STOPS = {
    'prospect', 'player', 'players', 'show', 'shows', 'need', 'needs',
    'ability', 'also', 'often', 'must', 'well', 'still', 'use', 'get',
    'make', 'look', 'help', 'work', 'time', 'year', 'team', 'game',
    'continue', 'develop', 'development', 'nfl', 'draft', 'college',
    'level', 'type', 'project', 'potential', 'upside', 'ceiling',
}

_base_stops = set(stopwords.words('english'))
NFL_STOPWORDS = (_base_stops - KEEP_WORDS) | CUSTOM_STOPS

print(f'Base NLTK stop words:  {len(_base_stops)}')
print(f'Words un-stopped:      {len(KEEP_WORDS & _base_stops)}')
print(f'Custom words added:    {len(CUSTOM_STOPS)}')
print(f'Final NFL stop list:   {len(NFL_STOPWORDS)}')
print(f'\nVerify kept words still in vocab (not stopped):')
print(sorted(KEEP_WORDS & _base_stops))
# Out:
# Base NLTK stop words:  198
# Words un-stopped:      8
# Custom words added:    35
# Final NFL stop list:   225
#
# Verify kept words still in vocab (not stopped):
# ['above', 'below', 'down', 'off', 'out', 'over', 'through', 'up']

# %% [markdown]
# ### 3b. Phrase Stitching — Pass A: Curated NFL Compound Terms
#
# These are applied as simple string replacements **before** tokenization,
# so the phrase context is preserved. Longest phrases run first to prevent partial matches.

# %%
# key = phrase (lowercase), value = replacement token
# Sorted longest-first at apply time to prevent partial matches
_NFL_PHRASE_MAP_RAW = {
    # ── Tri-grams (apply before bi-grams) ─────────────────────────────────────
    'change of direction':  'change_of_direction',
    'low pad level':        'low_pad_level',
    'run after catch':      'run_after_catch',
    'yards after contact':  'yards_after_contact',
    'yards after catch':    'yards_after_catch',
    'off the line':         'off_the_line',
    'off the ball':         'off_the_ball',
    'point of attack':      'point_of_attack',
    'get off the':          'get_off',        # catches 'get off the line' etc.
    # ── Bi-grams ──────────────────────────────────────────────────────────────
    'pad level':            'pad_level',
    'pass rush':            'pass_rush',
    'pass rusher':          'pass_rusher',
    'rush ability':         'rush_ability',
    'open field':           'open_field',
    'high cut':             'high_cut',
    'press coverage':       'press_coverage',
    'man coverage':         'man_coverage',
    'zone coverage':        'zone_coverage',
    'hand fighting':        'hand_fighting',
    'block shedding':       'block_shedding',
    'first step':           'first_step',
    'second level':         'second_level',
    'heavy hands':          'heavy_hands',
    'soft hands':           'soft_hands',
    'strong hands':         'strong_hands',
    'anchor strength':      'anchor_strength',
    'three down':           'three_down',
    'red zone':             'red_zone',
    'snap count':           'snap_count',
    'two gap':              'two_gap',
    'one gap':              'one_gap',
    'get off':              'get_off',
    'pass protection':      'pass_protection',
    'run blocking':         'run_blocking',
    'route running':        'route_running',
    'ball carrier':         'ball_carrier',
    'ball hawk':            'ball_hawk',
    'pass coverage':        'pass_coverage',
    'hip flexibility':      'hip_flexibility',
    'closing speed':        'closing_speed',
    'contact balance':      'contact_balance',
    'body control':         'body_control',
    'burst speed':          'burst_speed',
    'lateral quickness':    'lateral_quickness',
    'short area':           'short_area',
    'high motor':           'high_motor',
    'low center':           'low_center',
    'hand strength':        'hand_strength',
    'quick twitch':         'quick_twitch',
    'top end':              'top_end',
}

# Sort by length descending so tri-grams are replaced before bi-grams
NFL_PHRASE_MAP = dict(
    sorted(_NFL_PHRASE_MAP_RAW.items(), key=lambda x: len(x[0]), reverse=True)
)

print(f'Curated NFL phrases: {len(NFL_PHRASE_MAP)}')
print('\nSample (longest first):')
for k, v in list(NFL_PHRASE_MAP.items())[:8]:
    print(f'  "{k}" → "{v}"')
# Out:
# Curated NFL phrases: 50
#
# Sample (longest first):
#   "change of direction" → "change_of_direction"
#   "yards after contact" → "yards_after_contact"
#   "yards after catch" → "yards_after_catch"
#   "lateral quickness" → "lateral_quickness"
#   "run after catch" → "run_after_catch"
#   "point of attack" → "point_of_attack"
#   "anchor strength" → "anchor_strength"
#   "pass protection" → "pass_protection"

# %% [markdown]
# ### 3c. Preprocessing Function

# %%
lemmatizer = WordNetLemmatizer()

def nfl_preprocess(text: str, phrase_map: dict = NFL_PHRASE_MAP) -> str:
    """NFL-aware preprocessing pipeline."""
    if not isinstance(text, str) or not text.strip():
        return ''
    text = text.lower()

    # 1. Remove outcome-leaking phrases (longest first)
    for phrase in sorted(PHRASE_BLOCKLIST, key=len, reverse=True):
        text = text.replace(phrase, ' ')

    # 2. Normalize hyphens/dashes → spaces BEFORE phrase stitching
    #    so "pass-rush", "pass–rush", "pass—rush" all become "pass rush"
    #    and get caught by the phrase map below
    text = re.sub(r'[-\u2013\u2014]', ' ', text)

    # 3. Stitch curated NFL compound phrases
    for phrase, replacement in phrase_map.items():
        text = text.replace(phrase, replacement)

    # 4. Regex: keep letters, underscores (stitched tokens), spaces
    text = re.sub(r'[^a-z_\s]', ' ', text)

    # 5. Tokenize
    tokens = text.split()

    # 6. Stop word filter — always keep stitched tokens (contain '_')
    tokens = [t for t in tokens if '_' in t or t not in NFL_STOPWORDS]

    # 7. Lemmatize non-stitched tokens only
    tokens = [t if '_' in t else lemmatizer.lemmatize(t) for t in tokens]

    # 8. Drop short tokens (keep stitched phrases regardless)
    tokens = [t for t in tokens if len(t) > 1]

    return ' '.join(tokens)


# Also define the standard NLTK pipeline for side-by-side comparison
_std_stops = set(stopwords.words('english'))

def standard_preprocess(text: str) -> str:
    """Standard NLTK pipeline (same as rf_text_made_it) for comparison."""
    if not isinstance(text, str) or not text.strip():
        return ''
    text = text.lower()
    for phrase in sorted(PHRASE_BLOCKLIST, key=len, reverse=True):
        text = text.replace(phrase, ' ')
    text = re.sub(r'[^a-z\s]', ' ', text)
    tokens = [
        lemmatizer.lemmatize(w)
        for w in text.split()
        if w not in _std_stops and len(w) > 1
    ]
    return ' '.join(tokens)


print('Applying NFL preprocessing...')
df['text_nfl']      = df['combined_text'].apply(nfl_preprocess)
df['text_standard'] = df['combined_text'].apply(standard_preprocess)
df = df[df['text_nfl'] != ''].reset_index(drop=True)
print(f'Done. {len(df)} players with non-empty NFL-cleaned text.')

# Quick spot-check: verify hyphenated phrases are stitched correctly
test_cases = [
    'pass-rush talent with great get-off',
    'high-motor player with low pad-level issues',
    'route-running and man-coverage ability',
    'heavy-handed blocker with body-control problems',
]
print('\nHyphen normalization spot-check:')
for t in test_cases:
    print(f'  IN:  {t}')
    print(f'  OUT: {nfl_preprocess(t)}')
    print()
# Out:
# Applying NFL preprocessing...
# Done. 3139 players with non-empty NFL-cleaned text.
#
# Hyphen normalization spot-check:
#   IN:  pass-rush talent with great get-off
#   OUT: pass_rush talent great get_off
#
#   IN:  high-motor player with low pad-level issues
#   OUT: high_motor low_pad_level issue
#
#   IN:  route-running and man-coverage ability
#   OUT: route_running man_coverage
#
#   IN:  heavy-handed blocker with body-control problems
#   OUT: heavy handed blocker body_control problem

# %% [markdown]
# ### 3d. Phrase Stitching — Pass B: Data-Driven Bigram Discovery
#
# Run `BigramCollocationFinder` on the corpus **after** Pass A stitching to discover
# high-PMI bigrams the curated list missed. **Review the output** — add keepers to
# `NFL_PHRASE_MAP` above and re-run if desired.

# %%
# Tokenise the NFL-cleaned text for collocation discovery
# Only use non-stitched tokens for bigram finding (stitched tokens already handled)
_all_token_lists = [
    [t for t in text.split() if '_' not in t]   # exclude already-stitched phrases
    for text in df['text_nfl']
]

finder = BigramCollocationFinder.from_documents(_all_token_lists)
finder.apply_freq_filter(AUTO_PHRASE_MIN_FREQ)

# Score by PMI
scored = finder.score_ngrams(BigramAssocMeasures.pmi)

# Filter: both tokens must be non-stopword, alphabetic, len > 2
already_stitched = set(NFL_PHRASE_MAP.keys())
_curated_tokens  = {t for phrase in already_stitched for t in phrase.split()}

auto_phrases = [
    (w1, w2, score)
    for (w1, w2), score in scored
    if  w1 not in NFL_STOPWORDS
    and w2 not in NFL_STOPWORDS
    and w1.isalpha() and w2.isalpha()
    and len(w1) > 2  and len(w2) > 2
    and f'{w1} {w2}' not in already_stitched
][:AUTO_PHRASE_TOP_N]

auto_phrase_df = pd.DataFrame(auto_phrases, columns=['word1', 'word2', 'pmi'])
auto_phrase_df['phrase']      = auto_phrase_df['word1'] + ' ' + auto_phrase_df['word2']
auto_phrase_df['token']       = auto_phrase_df['word1'] + '_' + auto_phrase_df['word2']
auto_phrase_df['corpus_freq'] = auto_phrase_df.apply(
    lambda r: finder.ngram_fd[(r['word1'], r['word2'])], axis=1
)

print(f'Auto-discovered bigrams (freq ≥ {AUTO_PHRASE_MIN_FREQ}, top {AUTO_PHRASE_TOP_N} by PMI):')
print('Review these — add useful ones to NFL_PHRASE_MAP above and re-run\n')
print(auto_phrase_df[['phrase', 'token', 'pmi', 'corpus_freq']]
      .sort_values('pmi', ascending=False)
      .to_string(index=False))
# Out:
# Auto-discovered bigrams (freq ≥ 15, top 60 by PMI):
# Review these — add useful ones to NFL_PHRASE_MAP above and re-run
#
#                phrase                 token       pmi  corpus_freq
#           blue collar           blue_collar 14.206738           16
#          feast famine          feast_famine 14.075494           17
#          margin error          margin_error 14.075494           17
#            notre dame            notre_dame 14.075494           23
#             sand pant             sand_pant 13.631236           17
#        highlight reel        highlight_reel 13.561581           19
#          calling card          calling_card 13.384737           16
#            stat sheet            stat_sheet 13.376663           30
#             fine tune             fine_tune 13.289200           15
#           phone booth           phone_booth 13.044467           46
#        south carolina        south_carolina 12.727321           18
#             hear name             hear_name 12.616877           28
#              red flag              red_flag 12.554662           20
#             jet sweep             jet_sweep 12.411071           43
#     technically sound     technically_sound 12.398434           31
#              hot cold              hot_cold 12.362016           21
#          star recruit          star_recruit 12.003205           22
#            old rookie            old_rookie 11.952387           41
#         poorly thrown         poorly_thrown 11.871135           18
#            worker bee            worker_bee 11.857589           21
#       thickly muscled       thickly_muscled 11.821800           16
#         wasted motion         wasted_motion 11.758011           65
#              acl tear              acl_tear 11.728691           40
#           name called           name_called 11.557214           30
#  interference penalty  interference_penalty 11.522240           27
#          reliant upon          reliant_upon 11.520186           26
#           sub package           sub_package 11.402417           68
#      attention detail      attention_detail 11.341668           18
#           mean streak           mean_streak 11.227497           15
#           dual threat           dual_threat 11.206738           23
#        ideally suited        ideally_suited 11.147845           20
#            pluck tuck            pluck_tuck 11.123322           16
#       shrine practice       shrine_practice 11.109877           18
#           depth chart           depth_chart 11.062808           16
#          vocal leader          vocal_leader 11.019002           23
#         waist bending         waist_bending 11.014719           36
#          blitz pickup          blitz_pickup 10.952111           21
#           sure handed           sure_handed 10.835013           16
#        decision maker        decision_maker 10.791701           15
#            penn state            penn_state 10.778877           20
#        coaching staff        coaching_staff 10.730665           25
#           flat footed           flat_footed 10.722129           30
#            ohio state            ohio_state 10.636858           58
#              ole miss              ole_miss 10.560137           15
#         pass defensed         pass_defensed 10.551133           99
#            non factor            non_factor 10.499879           23
#           locker room           locker_room 10.444238           31
#               mid air               mid_air 10.392041           40
#    changing direction    changing_direction 10.372299           49
# completion percentage completion_percentage 10.164594           25
#           senior bowl           senior_bowl 10.144490           81
#             grab drag             grab_drag 10.126026           27
#          climb ladder          climb_ladder 10.104089           18
# warrant consideration warrant_consideration 10.088998           21
#            cross face            cross_face 10.025290           64
#             scout say             scout_say  9.994966           56
#         ankle flexion         ankle_flexion  9.882791           17
#      highly respected      highly_respected  9.875248           29
#    directional change    directional_change  9.863500           32
#         medical check         medical_check  9.839070           17

# %% [markdown]
# ## 4. Vocabulary Inspection
#
# What does the cleaned corpus actually look like? No model — just the tokens.

# %%
# ── Token frequency across all documents ──────────────────────────────────────
all_tokens = [t for text in df['text_nfl'] for t in text.split()]
token_counts = Counter(all_tokens)

# Split stitched vs regular
stitched_counts = {k: v for k, v in token_counts.items() if '_' in k}
regular_counts  = {k: v for k, v in token_counts.items() if '_' not in k}

print(f'Total tokens: {len(all_tokens):,}')
print(f'Unique tokens: {len(token_counts):,}  '
      f'(regular: {len(regular_counts):,}, stitched phrases: {len(stitched_counts):,})')

print('\n── Top 50 regular tokens (NFL-cleaned) ──────────────────────────────────')
top_regular = pd.Series(regular_counts).sort_values(ascending=False).head(50)
print(top_regular.to_frame('count').to_string())

print('\n── All stitched phrase tokens (Pass A curated + survivors) ───────────────')
stitched_series = pd.Series(stitched_counts).sort_values(ascending=False)
print(stitched_series.to_frame('count').to_string())
# Out:
# Total tokens: 404,430
# Unique tokens: 10,225  (regular: 10,152, stitched phrases: 73)
#
# ── Top 50 regular tokens (NFL-cleaned) ──────────────────────────────────
#            count
# play        6120
# run         3630
# up          3185
# hand        3155
# good        3153
# route       3056
# speed       2917
# lack        2898
# block       2820
# ball        2799
# tackle      2651
# average     2646
# out         2390
# size        2343
# catch       2330
# could       2211
# off         2096
# blocker     2081
# foot        2051
# strength    2007
# team        1852
# down        1714
# over        1650
# back        1617
# throw       1616
# power       1567
# body        1514
# frame       1512
# through     1473
# edge        1468
# hip         1421
# receiver    1413
# quickness   1392
# get         1375
# move        1355
# long        1352
# arm         1348
# pas         1346
# length      1328
# space       1328
# season      1319
# coverage    1313
# inside      1309
# field       1287
# athletic    1280
# end         1267
# below       1212
# rush        1199
# big         1193
# high        1172
#
# ── All stitched phrase tokens (Pass A curated + survivors) ───────────────
#                       count
# point_of_attack         660
# second_level            537
# body_control            484
# pass_protection         457
# man_coverage            404
# pass_rusher             391
# pad_level               380
# change_of_direction     374
# open_field              346
# short_area              342
# pass_rush               258
# contact_balance         179
# lateral_quickness       176
# press_coverage          137
# top_end                 129
# zone_coverage           123
# route_running           117
# strong_hands            109
# ball_carrier            101
# soft_hands              101
# get_off                  98
# hand_strength            96
# run_blocking             95
# high_cut                 91
# off_the_ball             90
# off_the_line             84
# red_zone                 78
# ball_carriers            77
# pass_rushers             73
# quick_twitch             58
# first_step               53
# yards_after_catch        49
# run_after_catch          47
# low_center               47
# two_gap                  44
# hand_fighting            43
# three_down               42
# heavy_hands              42
# closing_speed            31
# low_pad_level            27
# yards_after_contact      27
# anchor_strength          21
# ball_hawking             20
# second_levels            19
# two_gapper               18
# one_gapping              17
# one_gap                  17
# three_downs              16
# pass_rushing             14
# high_motor               14
# pass_rush_ability        13
# two_gapping              13
# two_gappers               9
# ball_hawk                 8
# pass_coverage             8
# hip_flexibility           6
# one_gapper                5
# short_areas               5
# rush_ability              4
# zone_coverages            4
# pass_rushes               4
# zone_gaps                 3
# get_off_the_ball          3
# snap_counts               3
# snap_count                3
# get_off_the_line          2
# two_gaps                  2
# off_the_ball_carrier      1
# one_gaps                  1
# one_gappers               1
# yards_after_contacts      1
# first_steps               1
# point_of_attacks          1

# %%
# ── Sanity checks ─────────────────────────────────────────────────────────────
should_be_absent = ['prospect', 'player', 'players', 'show', 'shows', 'need', 'needs',
                    'ability', 'nfl', 'draft', 'college']
should_be_present = ['high', 'low', 'heavy', 'deep', 'hard', 'soft', 'strong', 'quick',
                     'light', 'long', 'wide']

print('── Words that should be ABSENT (custom stops) ────────────────────────────')
for w in should_be_absent:
    cnt = token_counts.get(w, 0)
    status = '✓ ABSENT' if cnt == 0 else f'✗ PRESENT ({cnt}x)'
    print(f'  {w:20s} {status}')

print('\n── Words that should be PRESENT (un-stopped directionals) ───────────────')
for w in should_be_present:
    cnt = token_counts.get(w, 0)
    status = f'✓ PRESENT ({cnt}x)' if cnt > 0 else '✗ ABSENT'
    print(f'  {w:20s} {status}')
# Out:
# ── Words that should be ABSENT (custom stops) ────────────────────────────
#   prospect             ✗ PRESENT (33x)
#   player               ✓ ABSENT
#   players              ✓ ABSENT
#   show                 ✓ ABSENT
#   shows                ✓ ABSENT
#   need                 ✓ ABSENT
#   needs                ✓ ABSENT
#   ability              ✗ PRESENT (10x)
#   nfl                  ✓ ABSENT
#   draft                ✗ PRESENT (3x)
#   college              ✗ PRESENT (1x)
#
# ── Words that should be PRESENT (un-stopped directionals) ───────────────
#   high                 ✓ PRESENT (1172x)
#   low                  ✓ PRESENT (441x)
#   heavy                ✓ PRESENT (410x)
#   deep                 ✓ PRESENT (707x)
#   hard                 ✓ PRESENT (479x)
#   soft                 ✓ PRESENT (105x)
#   strong               ✓ PRESENT (645x)
#   quick                ✓ PRESENT (917x)
#   light                ✓ PRESENT (115x)
#   long                 ✓ PRESENT (1352x)
#   wide                 ✓ PRESENT (601x)

# %%
# ── Side-by-side sample: raw → standard NLTK → NFL-clean ──────────────────────
# Pick players whose raw text contains at least one curated phrase
phrase_keywords = ['pad level', 'change of direction', 'heavy hands',
                   'pass rush', 'run after catch', 'press coverage', 'high motor']

sample_indices = []
for kw in phrase_keywords:
    matches = df[df['combined_text'].str.lower().str.contains(kw, na=False)].index
    if len(matches) > 0:
        sample_indices.append(matches[0])
    if len(sample_indices) >= 5:
        break

# Also grab a couple of random players
import random; random.seed(42)
sample_indices += random.sample(list(df.index), min(3, len(df)))
sample_indices = list(dict.fromkeys(sample_indices))[:6]   # deduplicate, cap at 6

print('Side-by-side comparison — raw vs standard NLTK vs NFL-clean')
print('=' * 100)
for idx in sample_indices:
    row = df.loc[idx]
    print(f"\n[{row['Pos_Group']}] {row.get('player_name', idx)}  "
          f"grade={row.get('grade', '?')}  {TARGET}={row[TARGET]}")
    print(f"  RAW:      {str(row['combined_text'])[:200]}")
    print(f"  STANDARD: {row['text_standard'][:200]}")
    print(f"  NFL-CLEAN:{row['text_nfl'][:200]}")
    print('-' * 100)
# Out:
# Side-by-side comparison — raw vs standard NLTK vs NFL-clean
# ====================================================================================================
#
# [EDGE] Kony Ealy  grade=6.2  made_it_contract=1
#   RAW:      Big, athletic, ascending, pass-rush talent with the size, burst and flexibility to pressurize the edge as a right defensive end. Is not a finished product, particularly as a run defender, but should o
#   STANDARD: big athletic ascending pas rush talent size burst flexibility pressurize edge right defensive end finished product particularly run defender become disruptive strength technique savvy catch natural ph
#   NFL-CLEAN:big athletic ascending pass_rush talent size burst flexibility pressurize edge right defensive end finished product particularly run defender become disruptive strength technique savvy catch up natura
# ----------------------------------------------------------------------------------------------------
#
# [DB] Ahmad Dixon  grade=5.8  made_it_contract=0
#   RAW:      Box safety possessing the physical talent to compete in the NFL and even earn a starting job eventually if he can stay focused, commit to a playbook and hone his eyes. Should be able to factor readily
#   STANDARD: box safety possessing physical talent compete nfl even earn starting job eventually stay focused commit playbook hone eye able factor readily special team coverage limitation leave vulnerable would be
#   NFL-CLEAN:box safety possessing physical talent compete even earn starting job eventually stay focused commit playbook hone eye able factor readily special team coverage limitation leave vulnerable would best s
# ----------------------------------------------------------------------------------------------------
#
# [OL] Shon Coleman  grade=6.3  made_it_contract=0
#   RAW:      Coleman's strengths and weaknesses are strikingly similar to those of former Auburn left tackle Greg Robinson, but Coleman lacks the same level of athleticism. Coleman uses his length and redirect str
#   STANDARD: coleman strength weakness strikingly similar former auburn left tackle greg robinson coleman lack level athleticism coleman us length redirect strength overcome lunging waist bending issue highlighted
#   NFL-CLEAN:coleman strength weakness strikingly similar former auburn left tackle greg robinson coleman lack athleticism coleman us length redirect strength overcome lunging waist bending issue highlighted edge
# ----------------------------------------------------------------------------------------------------
#
# [DT] Anthony Johnson  grade=6.1  made_it_contract=0
#   RAW:      Big, athletic, overhyped defensive tackle who shows in flashes, but leaves evaluators wanting more and would have benefited from a more dominant junior season. Fits best in an even front, though he’s
#   STANDARD: big athletic overhyped defensive tackle show flash leaf evaluator wanting would benefited dominant junior season fit best even front though instant coffee tweener skill set unrefined project absolutel
#   NFL-CLEAN:big athletic overhyped defensive tackle flash leaf evaluator wanting would benefited dominant junior season fit best even front though instant coffee tweener skill set unrefined absolutely nose three
# ----------------------------------------------------------------------------------------------------
#
# [WR] Ty Montgomery  grade=6.1  made_it_contract=1
#   RAW:      Montgomery is a likable person with high character and an ability to leave a positive impression in draft interviews, but teams will still have to figure out how they want to use him. His hands might
#   STANDARD: montgomery likable person high character ability leave positive impression draft interview team still figure want use hand might trustworthy enough part three wide receiver set montgomery flip field c
#   NFL-CLEAN:montgomery likable person high character leave positive impression interview team figure out want hand might trustworthy enough part three wide receiver set montgomery flip field change game return mi
# ----------------------------------------------------------------------------------------------------
#
# [LB] Chapelle Russell  grade=5.49  made_it_contract=0
#   RAW:      Resilient, mentally tough linebacker whose ability to fight back after two ACL tears to the same knee should tell teams about his football character. Of course, the same ACL tears also tell teams that
#   STANDARD: resilient mentally tough linebacker whose ability fight back two acl tear knee tell team football character course acl tear also tell team durability could major concern russell trouble keeping weight
#   NFL-CLEAN:resilient mentally tough linebacker whose fight back two acl tear knee tell team football character course acl tear tell team durability could major concern russell trouble keeping weight past weighed
# ----------------------------------------------------------------------------------------------------
